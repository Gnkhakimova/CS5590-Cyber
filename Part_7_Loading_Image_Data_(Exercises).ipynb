# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnkhakimova/CS5590-Cyber/blob/master/Part_7_Loading_Image_Data_(Exercises).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Image Data
#
# So far we've been working with fairly artificial datasets that you wouldn't typically be using in real projects. Instead, you'll likely be dealing with full-sized images like you'd get from smart phone cameras. In this notebook, we'll look at how to load images and use them to train neural networks.
#
# We'll be using a [dataset of cat and dog photos](https://www.kaggle.com/c/dogs-vs-cats) available from Kaggle. Here are a couple example images:
#
# <img src='https://drive.google.com/uc?id=18heWkz2o8OTeJsv___Rtb_bKEhEr1I5u'>
#
# We'll use this dataset to train a neural network that can differentiate between cats and dogs. These days it doesn't seem like a big accomplishment, but five years ago it was a serious challenge for computer vision systems.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import sys
sys.path.append('content/drive/My Drive/CS5590Cyber/Lesson1_2/intro-to-pytorch')

import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms

import helper

# %% [markdown]
# The easiest way to load image data is with `datasets.ImageFolder` from `torchvision` ([documentation](http://pytorch.org/docs/master/torchvision/datasets.html#imagefolder)). In general you'll use `ImageFolder` like so:
#
# ```python
# dataset = datasets.ImageFolder('path/to/data', transform=transform)
# ```
#
# where `'path/to/data'` is the file path to the data directory and `transform` is a list of processing steps built with the [`transforms`](http://pytorch.org/docs/master/torchvision/transforms.html) module from `torchvision`. ImageFolder expects the files and directories to be constructed like so:
# ```
# root/dog/xxx.png
# root/dog/xxy.png
# root/dog/xxz.png
#
# root/cat/123.png
# root/cat/nsdf3.png
# root/cat/asd932_.png
# ```
#
# where each class has it's own directory (`cat` and `dog`) for the images. The images are then labeled with the class taken from the directory name. So here, the image `123.png` would be loaded with the class label `cat`. You can download the dataset already structured like this [from here](https://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip). I've also split it into a training set and test set.
#
# ### Transforms
#
# When you load in the data with `ImageFolder`, you'll need to define some transforms. For example, the images are different sizes but we'll need them to all be the same size for training. You can either resize them with `transforms.Resize()` or crop with `transforms.CenterCrop()`, `transforms.RandomResizedCrop()`, etc. We'll also need to convert the images to PyTorch tensors with `transforms.ToTensor()`. Typically you'll combine these transforms into a pipeline with `transforms.Compose()`, which accepts a list of transforms and runs them in sequence. It looks something like this to scale, then crop, then convert to a tensor:
#
# ```python
# transform = transforms.Compose([transforms.Resize(255),
#                                  transforms.CenterCrop(224),
#                                  transforms.ToTensor()])
#
# ```
#
# There are plenty of transforms available, I'll cover more in a bit and you can read through the [documentation](http://pytorch.org/docs/master/torchvision/transforms.html).
#
# ### Data Loaders
#
# With the `ImageFolder` loaded, you have to pass it to a [`DataLoader`](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader). The `DataLoader` takes a dataset (such as you would get from `ImageFolder`) and returns batches of images and the corresponding labels. You can set various parameters like the batch size and if the data is shuffled after each epoch.
#
# ```python
# dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)
# ```
#
# Here `dataloader` is a [generator](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/). To get data out of it, you need to loop through it or convert it to an iterator and call `next()`.
#
# ```python
# # Looping through it, get a batch on each loop
# for images, labels in dataloader:
#     pass
#
# # Get one batch
# images, labels = next(iter(dataloader))
# ```
#
# >**Exercise:** Load images from the `Cat_Dog_data/train` folder, define a few transforms, then build the dataloader.

# %%
# !unzip CatDogdata.zip
# Out:
# Archive:  CatDogdata.zip
#   inflating: Cat_Dog_data/.DS_Store
#  extracting: Cat_Dog_data/desktop.ini
#    creating: Cat_Dog_data/test/
#   inflating: Cat_Dog_data/test/.DS_Store
#    creating: Cat_Dog_data/test/cat/
#   inflating: Cat_Dog_data/test/cat/cat.11906.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11918.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11930.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11948.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11955.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11972.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11980.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11987.jpg
#   inflating: Cat_Dog_data/test/cat/cat.11995.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12003.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12014.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12026.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12028.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12031.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12075.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12078.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12079.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12121.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12124.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12143.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12146.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12155.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12161.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12172.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12185.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12251.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12259.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12260.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12273.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12283.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12291.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12294.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12298.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12309.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12349.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12352.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12356.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12364.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12366.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12368.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12369.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12371.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12393.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12418.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12426.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12434.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12452.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12459.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12481.jpg
#   inflating: Cat_Dog_data/test/cat/cat.12489.jpg
#    creating: Cat_Dog_data/test/dog/
#   inflating: Cat_Dog_data/test/dog/dog.114.jpg
#   inflating: Cat_Dog_data/test/dog/dog.132.jpg
#   inflating: Cat_Dog_data/test/dog/dog.143.jpg
#   inflating: Cat_Dog_data/test/dog/dog.146.jpg
#   inflating: Cat_Dog_data/test/dog/dog.150.jpg
#   inflating: Cat_Dog_data/test/dog/dog.168.jpg
#   inflating: Cat_Dog_data/test/dog/dog.17.jpg
#   inflating: Cat_Dog_data/test/dog/dog.197.jpg
#   inflating: Cat_Dog_data/test/dog/dog.204.jpg
#   inflating: Cat_Dog_data/test/dog/dog.206.jpg
#   inflating: Cat_Dog_data/test/dog/dog.225.jpg
#   inflating: Cat_Dog_data/test/dog/dog.226.jpg
#   inflating: Cat_Dog_data/test/dog/dog.23.jpg
#   inflating: Cat_Dog_data/test/dog/dog.231.jpg
#   inflating: Cat_Dog_data/test/dog/dog.239.jpg
#   inflating: Cat_Dog_data/test/dog/dog.243.jpg
#   inflating: Cat_Dog_data/test/dog/dog.250.jpg
#   inflating: Cat_Dog_data/test/dog/dog.258.jpg
#   inflating: Cat_Dog_data/test/dog/dog.26.jpg
#   inflating: Cat_Dog_data/test/dog/dog.260.jpg
#   inflating: Cat_Dog_data/test/dog/dog.297.jpg
#   inflating: Cat_Dog_data/test/dog/dog.300.jpg
#   inflating: Cat_Dog_data/test/dog/dog.304.jpg
#   inflating: Cat_Dog_data/test/dog/dog.310.jpg
#   inflating: Cat_Dog_data/test/dog/dog.338.jpg
#   inflating: Cat_Dog_data/test/dog/dog.343.jpg
#   inflating: Cat_Dog_data/test/dog/dog.350.jpg
#   inflating: Cat_Dog_data/test/dog/dog.376.jpg
#   inflating: Cat_Dog_data/test/dog/dog.378.jpg
#   inflating: Cat_Dog_data/test/dog/dog.392.jpg
#   inflating: Cat_Dog_data/test/dog/dog.422.jpg
#   inflating: Cat_Dog_data/train/cat/cat.8.jpg
#   inflating: Cat_Dog_data/train/cat/cat.80.jpg
#   inflating: Cat_Dog_data/train/cat/cat.81.jpg
#   inflating: Cat_Dog_data/train/cat/cat.82.jpg
#   inflating: Cat_Dog_data/train/cat/cat.84.jpg
#   inflating: Cat_Dog_data/train/cat/cat.85.jpg
#   inflating: Cat_Dog_data/train/cat/cat.86.jpg
#   inflating: Cat_Dog_data/train/cat/cat.87.jpg
#   inflating: Cat_Dog_data/train/cat/cat.89.jpg
#   inflating: Cat_Dog_data/train/cat/cat.9.jpg
#   inflating: Cat_Dog_data/train/cat/cat.90.jpg
#   inflating: Cat_Dog_data/train/cat/cat.91.jpg
#   inflating: Cat_Dog_data/train/cat/cat.93.jpg
#   inflating: Cat_Dog_data/train/cat/cat.94.jpg
#   inflating: Cat_Dog_data/train/cat/cat.96.jpg
#   inflating: Cat_Dog_data/train/cat/cat.97.jpg
#   inflating: Cat_Dog_data/train/cat/cat.98.jpg
#   inflating: Cat_Dog_data/train/cat/cat.99.jpg
#    creating: Cat_Dog_data/train/dog/
#   inflating: Cat_Dog_data/train/dog/dog.0.jpg
#   inflating: Cat_Dog_data/train/dog/dog.1.jpg
#   inflating: Cat_Dog_data/train/dog/dog.10.jpg
#   inflating: Cat_Dog_data/train/dog/dog.100.jpg
#   inflating: Cat_Dog_data/train/dog/dog.101.jpg
#   inflating: Cat_Dog_data/train/dog/dog.102.jpg
#   inflating: Cat_Dog_data/train/dog/dog.103.jpg
#   inflating: Cat_Dog_data/train/dog/dog.104.jpg
#   inflating: Cat_Dog_data/train/dog/dog.105.jpg
#   inflating: Cat_Dog_data/train/dog/dog.106.jpg
#   inflating: Cat_Dog_data/train/dog/dog.107.jpg
#   inflating: Cat_Dog_data/train/dog/dog.108.jpg
#   inflating: Cat_Dog_data/train/dog/dog.109.jpg
#   inflating: Cat_Dog_data/train/dog/dog.11.jpg
#   inflating: Cat_Dog_data/train/dog/dog.12.jpg
#   inflating: Cat_Dog_data/train/dog/dog.13.jpg
#   inflating: Cat_Dog_data/train/dog/dog.14.jpg
#   inflating: Cat_Dog_data/train/dog/dog.15.jpg
#   inflating: Cat_Dog_data/train/dog/dog.16.jpg
#   inflating: Cat_Dog_data/train/dog/dog.18.jpg
#   inflating: Cat_Dog_data/train/dog/dog.19.jpg
#   inflating: Cat_Dog_data/train/dog/dog.2.jpg
#   inflating: Cat_Dog_data/train/dog/dog.20.jpg
#   inflating: Cat_Dog_data/train/dog/dog.21.jpg
#   inflating: Cat_Dog_data/train/dog/dog.22.jpg
#   inflating: Cat_Dog_data/train/dog/dog.24.jpg
#   inflating: Cat_Dog_data/train/dog/dog.25.jpg
#   inflating: Cat_Dog_data/train/dog/dog.27.jpg
#   inflating: Cat_Dog_data/train/dog/dog.28.jpg
#   inflating: Cat_Dog_data/train/dog/dog.29.jpg
#   inflating: Cat_Dog_data/train/dog/dog.3.jpg
#   inflating: Cat_Dog_data/train/dog/dog.30.jpg
#   inflating: Cat_Dog_data/train/dog/dog.31.jpg
#   inflating: Cat_Dog_data/train/dog/dog.32.jpg
#   inflating: Cat_Dog_data/train/dog/dog.33.jpg
#   inflating: Cat_Dog_data/train/dog/dog.34.jpg
#   inflating: Cat_Dog_data/train/dog/dog.35.jpg
#   inflating: Cat_Dog_data/train/dog/dog.36.jpg
#   inflating: Cat_Dog_data/train/dog/dog.37.jpg
#   inflating: Cat_Dog_data/train/dog/dog.38.jpg
#   inflating: Cat_Dog_data/train/dog/dog.39.jpg
#   inflating: Cat_Dog_data/train/dog/dog.4.jpg
#   inflating: Cat_Dog_data/train/dog/dog.40.jpg
#   inflating: Cat_Dog_data/train/dog/dog.41.jpg
#   inflating: Cat_Dog_data/train/dog/dog.42.jpg
#   inflating: Cat_Dog_data/train/dog/dog.43.jpg
#   inflating: Cat_Dog_data/train/dog/dog.44.jpg
#   inflating: Cat_Dog_data/train/dog/dog.45.jpg
#   inflating: Cat_Dog_data/train/dog/dog.46.jpg
#   inflating: Cat_Dog_data/train/dog/dog.47.jpg
#   inflating: Cat_Dog_data/train/dog/dog.48.jpg
#   inflating: Cat_Dog_data/train/dog/dog.49.jpg
#   inflating: Cat_Dog_data/train/dog/dog.5.jpg
#   inflating: Cat_Dog_data/train/dog/dog.50.jpg
#   inflating: Cat_Dog_data/train/dog/dog.51.jpg
#   inflating: Cat_Dog_data/train/dog/dog.52.jpg
#   inflating: Cat_Dog_data/train/dog/dog.53.jpg
#   inflating: Cat_Dog_data/train/dog/dog.54.jpg
#   inflating: Cat_Dog_data/train/dog/dog.55.jpg
#   inflating: Cat_Dog_data/train/dog/dog.56.jpg
#   inflating: Cat_Dog_data/train/dog/dog.57.jpg
#   inflating: Cat_Dog_data/train/dog/dog.58.jpg
#   inflating: Cat_Dog_data/train/dog/dog.59.jpg
#   inflating: Cat_Dog_data/train/dog/dog.6.jpg
#   inflating: Cat_Dog_data/train/dog/dog.60.jpg
#   inflating: Cat_Dog_data/train/dog/dog.61.jpg
#   inflating: Cat_Dog_data/train/dog/dog.62.jpg
#   inflating: Cat_Dog_data/train/dog/dog.63.jpg
#   inflating: Cat_Dog_data/train/dog/dog.64.jpg
#   inflating: Cat_Dog_data/train/dog/dog.65.jpg
#   inflating: Cat_Dog_data/train/dog/dog.67.jpg
#   inflating: Cat_Dog_data/train/dog/dog.68.jpg
#   inflating: Cat_Dog_data/train/dog/dog.7.jpg
#   inflating: Cat_Dog_data/train/dog/dog.70.jpg
#   inflating: Cat_Dog_data/train/dog/dog.71.jpg
#   inflating: Cat_Dog_data/train/dog/dog.73.jpg
#   inflating: Cat_Dog_data/train/dog/dog.74.jpg
#   inflating: Cat_Dog_data/train/dog/dog.75.jpg
#   inflating: Cat_Dog_data/train/dog/dog.76.jpg
#   inflating: Cat_Dog_data/train/dog/dog.78.jpg
#   inflating: Cat_Dog_data/train/dog/dog.79.jpg
#   inflating: Cat_Dog_data/train/dog/dog.8.jpg
#   inflating: Cat_Dog_data/train/dog/dog.80.jpg
#   inflating: Cat_Dog_data/train/dog/dog.81.jpg
#   inflating: Cat_Dog_data/train/dog/dog.82.jpg
#   inflating: Cat_Dog_data/train/dog/dog.83.jpg
#   inflating: Cat_Dog_data/train/dog/dog.84.jpg
#   inflating: Cat_Dog_data/train/dog/dog.85.jpg
#   inflating: Cat_Dog_data/train/dog/dog.86.jpg
#   inflating: Cat_Dog_data/train/dog/dog.87.jpg
#   inflating: Cat_Dog_data/train/dog/dog.88.jpg
#   inflating: Cat_Dog_data/train/dog/dog.89.jpg
#   inflating: Cat_Dog_data/train/dog/dog.9.jpg
#   inflating: Cat_Dog_data/train/dog/dog.90.jpg
#   inflating: Cat_Dog_data/train/dog/dog.91.jpg
#   inflating: Cat_Dog_data/train/dog/dog.93.jpg
#   inflating: Cat_Dog_data/train/dog/dog.94.jpg
#   inflating: Cat_Dog_data/train/dog/dog.95.jpg
#   inflating: Cat_Dog_data/train/dog/dog.96.jpg
#   inflating: Cat_Dog_data/train/dog/dog.97.jpg

# %%
data_dir = 'Cat_Dog_data/train'

transform = transforms.Compose([transforms.Resize(255),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor()])  
dataset = datasets.ImageFolder(data_dir, transform=transform) # TODO: create the ImageFolder
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True) # TODO: use the ImageFolder dataset to create the DataLoader

# %%
# Run this to test your data loader
images, labels = next(iter(dataloader))
helper.imshow(images[0], normalize=False)

# %% [markdown]
# If you loaded the data correctly, you should see something like this (your image will be different):
#
# <img src='https://drive.google.com/uc?id=1TW9U--Dgw0g_rFsMsQpynM4QBXrOtGPb' width=244>

# %% [markdown]
# ## Data Augmentation
#
# A common strategy for training neural networks is to introduce randomness in the input data itself. For example, you can randomly rotate, mirror, scale, and/or crop your images during training. This will help your network generalize as it's seeing the same images but in different locations, with different sizes, in different orientations, etc.
#
# To randomly rotate, scale and crop, then flip your images you would define your transforms like this:
#
# ```python
# train_transforms = transforms.Compose([transforms.RandomRotation(30),
#                                        transforms.RandomResizedCrop(224),
#                                        transforms.RandomHorizontalFlip(),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.5, 0.5, 0.5],
#                                                             [0.5, 0.5, 0.5])])
# ```
#
# You'll also typically want to normalize images with `transforms.Normalize`. You pass in a list of means and list of standard deviations, then the color channels are normalized like so
#
# ```input[channel] = (input[channel] - mean[channel]) / std[channel]```
#
# Subtracting `mean` centers the data around zero and dividing by `std` squishes the values to be between -1 and 1. Normalizing helps keep the network work weights near zero which in turn makes backpropagation more stable. Without normalization, networks will tend to fail to learn.
#
# You can find a list of all [the available transforms here](http://pytorch.org/docs/0.3.0/torchvision/transforms.html). When you're testing however, you'll want to use images that aren't altered (except you'll need to normalize the same way). So, for validation/test images, you'll typically just resize and crop.
#
# >**Exercise:** Define transforms for training data and testing data below. Leave off normalization for now.

# %%
data_dir = 'Cat_Dog_data'

# TODO: Define transforms for the training data and testing data
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor()]) 

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor()])


# Pass transforms in here, then run the next cell to see how the transforms look
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=32)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32)

# %%
# change this to the trainloader or testloader 
data_iter = iter(testloader)

images, labels = next(data_iter)
fig, axes = plt.subplots(figsize=(10,4), ncols=4)
for ii in range(4):
    ax = axes[ii]
    helper.imshow(images[ii], ax=ax, normalize=False)

# %% [markdown]
# Your transformed images should look something like this.
#
# <center>Training examples:</center>
# <img src='https://drive.google.com/uc?id=1_KaXsIAM_MV03kEnDfUrXDHWbw2P7yOu' width=500px>
#
# <center>Testing examples:</center>
# <img src='https://drive.google.com/uc?id=1emepCLdUOeyQ41T8oVPVrS7boWdJ42pf' width=500px>

# %% [markdown]
# At this point you should be able to load data for training and testing. Now, you should try building a network that can classify cats vs dogs. This is quite a bit more complicated than before with the MNIST and Fashion-MNIST datasets. To be honest, you probably won't get it to work with a fully-connected network, no matter how deep. These images have three color channels and at a higher resolution (so far you've seen 28x28 images which are tiny).
#
# In the next part, I'll show you how to use a pre-trained network to build a model that can actually solve this problem.

# %%
# Optional TODO: Attempt to build a network to classify cats vs dogs from this dataset
from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(150528, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)

        # Dropout module with 0.2 drop probability
        self.dropout = nn.Dropout(p=0.2)

    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)

        # Now with dropout
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))

        # output so no dropout here
        x = F.log_softmax(self.fc4(x), dim=1)

        return x

# %%
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 7
steps = 0

train_losses, test_losses, accuracy_losses = [], [], []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    else:
      test_loss = 0
      accuracy = 0
        ## TODO: Implement the validation pass and print out the validation accuracy,
      with torch.no_grad():
          model.eval()
          for images, labels in testloader:
              log_ps=model(images)
              test_loss += criterion(log_ps,labels)
              ps = torch.exp(log_ps)
              top_p, top_class = ps.topk(1,dim=1)
              equals = top_class == labels.view(*top_class.shape)            
              accuracy += torch.mean(equals.type(torch.FloatTensor))
              
      model.train()
            
      train_losses.append(running_loss/len(trainloader))
      test_losses.append(test_loss/len(testloader))
      accuracy_losses.append(accuracy/len(testloader))
            
      print("Epoch: {}/{}.. ".format(e+1, epochs),
            "Training Loss: {:.3f}..".format(running_loss/len(trainloader)),
            "Test Loss: {:.3f}..".format(test_loss/len(testloader)),
            "Test Accuracy: {:.3f}..".format(accuracy/len(testloader)))
# Out:
# Epoch: 1/7..  Training Loss: 67.871.. Test Loss: 47.331.. Test Accuracy: 0.609..
# Epoch: 2/7..  Training Loss: 45.306.. Test Loss: 0.667.. Test Accuracy: 0.672..
# Epoch: 3/7..  Training Loss: 3.433.. Test Loss: 2.195.. Test Accuracy: 0.609..
# Epoch: 4/7..  Training Loss: 2.783.. Test Loss: 0.794.. Test Accuracy: 0.609..
# Epoch: 5/7..  Training Loss: 1.363.. Test Loss: 0.711.. Test Accuracy: 0.609..
# Epoch: 6/7..  Training Loss: 0.892.. Test Loss: 0.670.. Test Accuracy: 0.609..
# Epoch: 7/7..  Training Loss: 0.869.. Test Loss: 0.673.. Test Accuracy: 0.609..

# %%
import matplotlib.pyplot as plt
plt.plot(train_losses, label = "Train Losses")
plt.plot(test_losses, label = "Test Losses")
plt.legend()

# %%
import matplotlib.pyplot as plt
plt.plot(accuracy_losses, label = "Accuracy")
plt.legend()

# %%
def view_classify(img, ps, version="MNIST"):
    ''' Function for viewing an image and it's predicted classes.
    '''
    ps = ps.data.numpy().squeeze()

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    ax2.barh(np.arange(10), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    if version == "MNIST":
        ax2.set_yticklabels(np.arange(10))
    elif version == "CatDog":
        ax2.set_yticklabels(['Cat',
                            'Dog'], size='small');
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

    plt.tight_layout()

# %%
# Test out your network!

model.eval()

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.view(1, 150528)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output)

# Plot the image and probabilities
view_classify(img.view(1, 28, 28), ps, version='CatDog')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-a959ac98a4e1> in <module>()
#      15
#      16 # Plot the image and probabilities
# ---> 17 view_classify(img.view(1, 28, 28), ps, version='CatDog')
#
# RuntimeError: shape '[1, 28, 28]' is invalid for input of size 150528
